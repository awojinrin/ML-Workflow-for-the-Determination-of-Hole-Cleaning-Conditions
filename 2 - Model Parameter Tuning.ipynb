# %%
from model_funcs import gsearch, rsearch
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('cleaned_data.csv')
data.head()
# Out:
#    Density  YP  Temperature  ROP  Pipe rotation  Flow rate  Inclination  \
# 0    8.314  20           80   30              0        100           90
# 1    8.314  20           80   30              0        200           90
# 2    8.314  20           80   30             80        100           90
# 3    8.314  20           80   30             80        200           90
# 4    8.314  20          180   30              0        100           90
#
#    Eccentricity  Concentration
# 0         0.881           0.35
# 1         0.881           0.14
# 2         0.881           0.06
# 3         0.881           0.02
# 4         0.881           0.11

# %%
X_train, X_test, y_train, y_test = data_split(data)

# %% [markdown]
# ## Parameter Tuning

# %%
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ### Random Forest

# %%
forest_rparams = {'n_estimators': np.logspace(1, 4, 50).astype(int), 'max_depth': np.logspace(1, 3, 20).astype(int), 'bootstrap': [True, False]}

# %%
forest_rsearch = rsearch(iter = 200, est = RandomForestRegressor(criterion='mse', random_state=42), params=forest_rparams, x=X_train, y=y_train)
# Out:
# c:\Users\Thompson\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(

# %%
pd.DataFrame(forest_rsearch.cv_results_).sort_values(by = 'mean_test_score', ascending= False).head(10).iloc[:, 4:8]
# Out:
#     param_n_estimators param_max_depth param_bootstrap  \
# 197                 71              12            True
# 199                 47              26            True
# 104                 35             615            True
# 83                  26             183            True
# 191                 62              10            True
# 189                 62              33            True
# 14                 910              12            True
# 24                 517             483            True
# 153                686              10            True
# 176                109              42            True
#
#                                                 params
# 197  {'n_estimators': 71, 'max_depth': 12, 'bootstr...
# 199  {'n_estimators': 47, 'max_depth': 26, 'bootstr...
# 104  {'n_estimators': 35, 'max_depth': 615, 'bootst...
# 83   {'n_estimators': 26, 'max_depth': 183, 'bootst...
# 191  {'n_estimators': 62, 'max_depth': 10, 'bootstr...
# 189  {'n_estimators': 62, 'max_depth': 33, 'bootstr...
# 14   {'n_estimators': 910, 'max_depth': 12, 'bootst...
# 24   {'n_estimators': 517, 'max_depth': 483, 'boots...
# 153  {'n_estimators': 686, 'max_depth': 10, 'bootst...
# 176  {'n_estimators': 109, 'max_depth': 42, 'bootst...

# %%
forest_rsearch.best_estimator_
# Out:
# RandomForestRegressor(criterion='mse', max_depth=12, n_estimators=71)

# %%
forest_gparams = {'max_depth': np.arange(20, 200, 5), 'n_estimators': np.arange(5, 70, 2)}

# %%
forest_gsearch = gsearch(est = RandomForestRegressor(criterion = 'squared_error', bootstrap=True, random_state=42), 
                    params=forest_gparams, x=X_train, y=y_train)

# %%
pd.DataFrame(forest_gsearch.cv_results_).sort_values(by = 'mean_test_score', ascending= False).head(10).iloc[:, 4:8]
# Out:
#      param_max_depth param_n_estimators  \
# 1152             190                 65
# 30                20                 65
# 921              155                 65
# 888              150                 65
# 855              145                 65
# 822              140                 65
# 63                25                 65
# 1185             195                 65
# 789              135                 65
# 756              130                 65
#
#                                       params  split0_test_score
# 1152  {'max_depth': 190, 'n_estimators': 65}          -0.041979
# 30     {'max_depth': 20, 'n_estimators': 65}          -0.041979
# 921   {'max_depth': 155, 'n_estimators': 65}          -0.041979
# 888   {'max_depth': 150, 'n_estimators': 65}          -0.041979
# 855   {'max_depth': 145, 'n_estimators': 65}          -0.041979
# 822   {'max_depth': 140, 'n_estimators': 65}          -0.041979
# 63     {'max_depth': 25, 'n_estimators': 65}          -0.041979
# 1185  {'max_depth': 195, 'n_estimators': 65}          -0.041979
# 789   {'max_depth': 135, 'n_estimators': 65}          -0.041979
# 756   {'max_depth': 130, 'n_estimators': 65}          -0.041979

# %%
forest_gparams2 = {'max_depth': np.arange(150, 200), 'n_estimators': np.arange(35, 70)}

# %%
forest_gsearch2 = gsearch(est = RandomForestRegressor(criterion = 'squared_error', random_state=42, bootstrap=True), 
                    params=forest_gparams2, x=X_train, y=y_train)

# %%
pd.DataFrame(forest_gsearch2.cv_results_).sort_values(by = 'mean_test_score', ascending= False).head(10).iloc[:, 4:8]
# Out:
#      param_max_depth param_n_estimators  \
# 24               150                 59
# 70               152                 35
# 681              169                 51
# 1564             194                 59
# 1689             198                 44
# 1186             183                 66
# 1664             197                 54
# 1590             195                 50
# 1379             189                 49
# 215              156                 40
#
#                                       params  split0_test_score
# 24    {'max_depth': 150, 'n_estimators': 59}          -0.039787
# 70    {'max_depth': 152, 'n_estimators': 35}          -0.038164
# 681   {'max_depth': 169, 'n_estimators': 51}          -0.036818
# 1564  {'max_depth': 194, 'n_estimators': 59}          -0.037362
# 1689  {'max_depth': 198, 'n_estimators': 44}          -0.038176
# 1186  {'max_depth': 183, 'n_estimators': 66}          -0.039807
# 1664  {'max_depth': 197, 'n_estimators': 54}          -0.043121
# 1590  {'max_depth': 195, 'n_estimators': 50}          -0.037107
# 1379  {'max_depth': 189, 'n_estimators': 49}          -0.036948
# 215   {'max_depth': 156, 'n_estimators': 40}          -0.043675

# %%
forest_gparams3 = {'max_depth': np.arange(150, 200), 'n_estimators': np.arange(49, 68)}

# %%
forest_gsearch3 = gsearch(est = RandomForestRegressor(criterion = 'squared_error', random_state = 42,  
                    bootstrap=True), params=forest_gparams3, x=X_train, y=y_train)

# %%
pd.DataFrame(forest_gsearch3.cv_results_).sort_values(by = 'mean_test_score', ascending= False).head(10).iloc[:, 4:8]
# Out:
#     param_max_depth param_n_estimators  \
# 492             175                 66
# 302             165                 66
# 549             178                 66
# 815             192                 66
# 625             182                 66
# 321             166                 66
# 207             160                 66
# 929             198                 66
# 416             171                 66
# 36              151                 66
#
#                                      params  split0_test_score
# 492  {'max_depth': 175, 'n_estimators': 66}          -0.041804
# 302  {'max_depth': 165, 'n_estimators': 66}          -0.041804
# 549  {'max_depth': 178, 'n_estimators': 66}          -0.041804
# 815  {'max_depth': 192, 'n_estimators': 66}          -0.041804
# 625  {'max_depth': 182, 'n_estimators': 66}          -0.041804
# 321  {'max_depth': 166, 'n_estimators': 66}          -0.041804
# 207  {'max_depth': 160, 'n_estimators': 66}          -0.041804
# 929  {'max_depth': 198, 'n_estimators': 66}          -0.041804
# 416  {'max_depth': 171, 'n_estimators': 66}          -0.041804
# 36   {'max_depth': 151, 'n_estimators': 66}          -0.041804

# %%
forest_gsearch3.best_estimator_
# Out:
# RandomForestRegressor(max_depth=150, n_estimators=66, random_state=42)

# %% [markdown]
# ### Gradient Boosting

# %%
gb_rparams = {'loss':['squared_error', 'lad', 'huber'],
             'learning_rate': np.logspace(-3, 0, 10),
             'n_estimators': np.arange(50, 200, 5),
             'subsample': [.6, .7, .8, .9, 1],
             'max_depth': np.arange(2, 11)}

# %%
gb_reg = GradientBoostingRegressor(random_state = 42, n_iter_no_change = 5, validation_fraction = .15)
gb_rsearch = rsearch(iter = 4050, est = gb_reg, params=gb_rparams, x=X_train, y=y_train)

# %%
pd.DataFrame(gb_rsearch.cv_results_).sort_values(by = 'mean_test_score', ascending= False).head(10).iloc[:, 4:10]
# Out:
#      param_subsample param_n_estimators param_max_depth param_loss  \
# 1632             0.9                155               2         ls
# 2402             0.9                130               2         ls
# 3021             0.9                185               2         ls
# 605              0.9                 60               2         ls
# 3433             0.9                150               2         ls
# 182                1                180               2      huber
# 1865               1                 75               2      huber
# 3864             0.9                155               2         ls
# 3892             0.9                 85               2         ls
# 1319             0.9                160               2         ls
#
#      param_learning_rate                                             params
# 1632            0.464159  {'subsample': 0.9, 'n_estimators': 155, 'max_d...
# 2402            0.464159  {'subsample': 0.9, 'n_estimators': 130, 'max_d...
# 3021            0.464159  {'subsample': 0.9, 'n_estimators': 185, 'max_d...
# 605             0.464159  {'subsample': 0.9, 'n_estimators': 60, 'max_de...
# 3433            0.464159  {'subsample': 0.9, 'n_estimators': 150, 'max_d...
# 182             0.464159  {'subsample': 1, 'n_estimators': 180, 'max_dep...
# 1865            0.464159  {'subsample': 1, 'n_estimators': 75, 'max_dept...
# 3864            0.215443  {'subsample': 0.9, 'n_estimators': 155, 'max_d...
# 3892            0.215443  {'subsample': 0.9, 'n_estimators': 85, 'max_de...
# 1319            0.215443  {'subsample': 0.9, 'n_estimators': 160, 'max_d...

# %%
gb_rsearch.best_estimator_
# Out:
# GradientBoostingRegressor(learning_rate=0.46415888336127775, loss='ls',
#                           max_depth=2, n_estimators=60, n_iter_no_change=5,
#                           random_state=42, subsample=0.9,
#                           validation_fraction=0.15)

# %%
gb_gparams = {'learning_rate': np.logspace(-1.5, 0, 10),
             'n_estimators': np.arange(60, 160, 5),
             'subsample': [.75, .8, .85, .9, .95],
             'max_depth': np.arange(2, 9)}

# %%
gb_reg2 = GradientBoostingRegressor(random_state = 42, n_iter_no_change = 5, validation_fraction = .15, loss = 'squared_error')
gb_gsearch = gsearch(est = gb_reg2, params=gb_gparams, x=X_train, y=y_train)

# %%
pd.DataFrame(gb_gsearch.cv_results_).sort_values(by = 'mean_test_score', ascending= False).head(10).iloc[:, 4:9]
# Out:
#      param_learning_rate param_max_depth param_n_estimators param_subsample  \
# 4903            0.464159               2                 60             0.9
# 4923            0.464159               2                 80             0.9
# 4948            0.464159               2                105             0.9
# 4913            0.464159               2                 70             0.9
# 4933            0.464159               2                 90             0.9
# 4983            0.464159               2                140             0.9
# 4973            0.464159               2                130             0.9
# 4938            0.464159               2                 95             0.9
# 4968            0.464159               2                125             0.9
# 4963            0.464159               2                120             0.9
#
#                                                  params
# 4903  {'learning_rate': 0.46415888336127775, 'max_de...
# 4923  {'learning_rate': 0.46415888336127775, 'max_de...
# 4948  {'learning_rate': 0.46415888336127775, 'max_de...
# 4913  {'learning_rate': 0.46415888336127775, 'max_de...
# 4933  {'learning_rate': 0.46415888336127775, 'max_de...
# 4983  {'learning_rate': 0.46415888336127775, 'max_de...
# 4973  {'learning_rate': 0.46415888336127775, 'max_de...
# 4938  {'learning_rate': 0.46415888336127775, 'max_de...
# 4968  {'learning_rate': 0.46415888336127775, 'max_de...
# 4963  {'learning_rate': 0.46415888336127775, 'max_de...

# %%
gb_gparams2 = {'learning_rate': np.logspace(-1, 0, 10),
             'n_estimators': np.arange(60, 160, 5),
             'subsample': [ .84, .86, .88, .9, .92, .94, .96, .98],
             'max_depth': np.arange(2, 5)}

# %%
gb_gsearch2 = gsearch(est = gb_reg2, params=gb_gparams2, x=X_train, y=y_train)

# %%
pd.DataFrame(gb_gsearch2.cv_results_).sort_values(by = 'mean_test_score', ascending= False).head(10).iloc[:, 4:9]
# Out:
#      param_learning_rate param_max_depth param_n_estimators param_subsample  \
# 2485            0.359381               2                110            0.94
# 2549            0.359381               2                150            0.94
# 2469            0.359381               2                100            0.94
# 2493            0.359381               2                115            0.94
# 2509            0.359381               2                125            0.94
# 2429            0.359381               2                 75            0.94
# 2557            0.359381               2                155            0.94
# 2437            0.359381               2                 80            0.94
# 2461            0.359381               2                 95            0.94
# 2517            0.359381               2                130            0.94
#
#                                                  params
# 2485  {'learning_rate': 0.35938136638046275, 'max_de...
# 2549  {'learning_rate': 0.35938136638046275, 'max_de...
# 2469  {'learning_rate': 0.35938136638046275, 'max_de...
# 2493  {'learning_rate': 0.35938136638046275, 'max_de...
# 2509  {'learning_rate': 0.35938136638046275, 'max_de...
# 2429  {'learning_rate': 0.35938136638046275, 'max_de...
# 2557  {'learning_rate': 0.35938136638046275, 'max_de...
# 2437  {'learning_rate': 0.35938136638046275, 'max_de...
# 2461  {'learning_rate': 0.35938136638046275, 'max_de...
# 2517  {'learning_rate': 0.35938136638046275, 'max_de...

# %%
gb_gparams3 = {'learning_rate': np.logspace(-0.8, -0.2, 20),
             'n_estimators': np.arange(60, 160, 2),
             'subsample': np.arange(0.9, 1, 0.01),
             'max_depth': [2,3]}

# %%
gb_gsearch3 = gsearch(est = gb_reg2, params=gb_gparams3, x=X_train, y=y_train)

# %%
pd.DataFrame(gb_gsearch3.cv_results_).sort_values(by = 'mean_test_score', ascending= False).head(10).iloc[:, 4:9]
# Out:
#       param_learning_rate param_max_depth param_n_estimators param_subsample  \
# 11360             0.35267               2                132             0.9
# 11130             0.35267               2                 86             0.9
# 11140             0.35267               2                 88             0.9
# 11141             0.35267               2                 88            0.91
# 11150             0.35267               2                 90             0.9
# 11151             0.35267               2                 90            0.91
# 11160             0.35267               2                 92             0.9
# 11161             0.35267               2                 92            0.91
# 11170             0.35267               2                 94             0.9
# 11171             0.35267               2                 94            0.91
#
#                                                   params
# 11360  {'learning_rate': 0.352669921417466, 'max_dept...
# 11130  {'learning_rate': 0.352669921417466, 'max_dept...
# 11140  {'learning_rate': 0.352669921417466, 'max_dept...
# 11141  {'learning_rate': 0.352669921417466, 'max_dept...
# 11150  {'learning_rate': 0.352669921417466, 'max_dept...
# 11151  {'learning_rate': 0.352669921417466, 'max_dept...
# 11160  {'learning_rate': 0.352669921417466, 'max_dept...
# 11161  {'learning_rate': 0.352669921417466, 'max_dept...
# 11170  {'learning_rate': 0.352669921417466, 'max_dept...
# 11171  {'learning_rate': 0.352669921417466, 'max_dept...

# %%
gb_gsearch3.best_estimator_
# Out:
# GradientBoostingRegressor(learning_rate=0.352669921417466, max_depth=2,
#                           n_estimators=60, n_iter_no_change=5, random_state=42,
#                           subsample=0.9, validation_fraction=0.15)

# %%
gb_gparams4 = {'learning_rate': np.arange(0.3, 0.4, 0.005),
             'n_estimators': np.arange(60, 140, 1),
             'subsample': [0.92, 0.93]}

# %%
gb_reg3 = GradientBoostingRegressor(random_state = 42, n_iter_no_change = 5, validation_fraction = .15, loss = 'squared_error', max_depth = 2)
gb_gsearch4 = gsearch(est = gb_reg3, params=gb_gparams4, x=X_train, y=y_train)

# %%
pd.DataFrame(gb_gsearch4.cv_results_).sort_values(by = 'mean_test_score', ascending= False).head(10).iloc[:, 4:9]
# Out:
#      param_learning_rate param_n_estimators param_subsample  \
# 2401               0.375                 60            0.93
# 2400               0.375                 60            0.92
# 2502               0.375                111            0.92
# 2503               0.375                111            0.93
# 2504               0.375                112            0.92
# 2505               0.375                112            0.93
# 2506               0.375                113            0.92
# 2507               0.375                113            0.93
# 2508               0.375                114            0.92
# 2509               0.375                114            0.93
#
#                                                  params  split0_test_score
# 2401  {'learning_rate': 0.37500000000000006, 'n_esti...           -0.04029
# 2400  {'learning_rate': 0.37500000000000006, 'n_esti...           -0.04029
# 2502  {'learning_rate': 0.37500000000000006, 'n_esti...           -0.04029
# 2503  {'learning_rate': 0.37500000000000006, 'n_esti...           -0.04029
# 2504  {'learning_rate': 0.37500000000000006, 'n_esti...           -0.04029
# 2505  {'learning_rate': 0.37500000000000006, 'n_esti...           -0.04029
# 2506  {'learning_rate': 0.37500000000000006, 'n_esti...           -0.04029
# 2507  {'learning_rate': 0.37500000000000006, 'n_esti...           -0.04029
# 2508  {'learning_rate': 0.37500000000000006, 'n_esti...           -0.04029
# 2509  {'learning_rate': 0.37500000000000006, 'n_esti...           -0.04029

# %%
gb_gsearch4.best_estimator_
# Out:
# GradientBoostingRegressor(learning_rate=0.37500000000000006, max_depth=2,
#                           n_estimators=60, n_iter_no_change=5, random_state=42,
#                           subsample=0.92, validation_fraction=0.15)

# %% [markdown]
# ### Adaptive Boosting (AdaBoost)

# %%
adb_rparams = {'learning_rate': np.logspace(-3, 1, 12),
          'loss' : ['linear', 'square', 'exponential'],
          'n_estimators': np.arange(5,200, 5),
          'base_estimator': [GradientBoostingRegressor(random_state = 42), Ridge(alpha=0.01, random_state=6, solver='svd'), DecisionTreeRegressor(max_depth = 7)]
          }

# %%
adb_rsearch = rsearch(iter = 750, est = AdaBoostRegressor(random_state = 42), params=adb_rparams, x=X_train, y=y_train)

# %%
pd.DataFrame(adb_rsearch.cv_results_).sort_values(by = 'mean_test_score', ascending= False).head(10).iloc[:, 4:9]
# Out:
#     param_n_estimators   param_loss param_learning_rate  \
# 688                 60  exponential               0.001
# 420                125  exponential               0.001
# 575                120  exponential             0.00231
# 298                135  exponential             0.00231
# 244                130  exponential             0.00231
# 686                165  exponential               0.001
# 230                 40  exponential             0.00231
# 330                160  exponential               0.001
# 592                100  exponential             0.00231
# 3                  190  exponential             0.00231
#
#                            param_base_estimator  \
# 688  GradientBoostingRegressor(random_state=42)
# 420  GradientBoostingRegressor(random_state=42)
# 575  GradientBoostingRegressor(random_state=42)
# 298  GradientBoostingRegressor(random_state=42)
# 244  GradientBoostingRegressor(random_state=42)
# 686  GradientBoostingRegressor(random_state=42)
# 230  GradientBoostingRegressor(random_state=42)
# 330  GradientBoostingRegressor(random_state=42)
# 592  GradientBoostingRegressor(random_state=42)
# 3    GradientBoostingRegressor(random_state=42)
#
#                                                 params
# 688  {'n_estimators': 60, 'loss': 'exponential', 'l...
# 420  {'n_estimators': 125, 'loss': 'exponential', '...
# 575  {'n_estimators': 120, 'loss': 'exponential', '...
# 298  {'n_estimators': 135, 'loss': 'exponential', '...
# 244  {'n_estimators': 130, 'loss': 'exponential', '...
# 686  {'n_estimators': 165, 'loss': 'exponential', '...
# 230  {'n_estimators': 40, 'loss': 'exponential', 'l...
# 330  {'n_estimators': 160, 'loss': 'exponential', '...
# 592  {'n_estimators': 100, 'loss': 'exponential', '...
# 3    {'n_estimators': 190, 'loss': 'exponential', '...

# %%
adb_rsearch.best_estimator_
# Out:
# AdaBoostRegressor(base_estimator=GradientBoostingRegressor(random_state=42),
#                   learning_rate=0.001, loss='exponential', n_estimators=60,
#                   random_state=42)

# %%
adb_gparams = gparams = {'learning_rate': np.logspace(-4, -2, 10),
          'n_estimators': np.arange(50, 160, 5)}

# %%
adb_gsearch = gsearch(est = AdaBoostRegressor(loss = 'exponential', base_estimator = GradientBoostingRegressor(random_state=42), 
                random_state = 42), params=adb_gparams, x=X_train, y=y_train)

# %%
pd.DataFrame(adb_gsearch.cv_results_).sort_values(by = 'mean_test_score', ascending= False).head(10).iloc[:, 4:7]
# Out:
#    param_learning_rate param_n_estimators  \
# 79            0.000464                115
# 78            0.000464                110
# 84            0.000464                140
# 60            0.000278                130
# 15              0.0001                125
# 81            0.000464                125
# 37            0.000167                125
# 13              0.0001                115
# 45            0.000278                 55
# 82            0.000464                130
#
#                                                params
# 79  {'learning_rate': 0.00046415888336127773, 'n_e...
# 78  {'learning_rate': 0.00046415888336127773, 'n_e...
# 84  {'learning_rate': 0.00046415888336127773, 'n_e...
# 60  {'learning_rate': 0.0002782559402207126, 'n_es...
# 15     {'learning_rate': 0.0001, 'n_estimators': 125}
# 81  {'learning_rate': 0.00046415888336127773, 'n_e...
# 37  {'learning_rate': 0.0001668100537200059, 'n_es...
# 13     {'learning_rate': 0.0001, 'n_estimators': 115}
# 45  {'learning_rate': 0.0002782559402207126, 'n_es...
# 82  {'learning_rate': 0.00046415888336127773, 'n_e...

# %%
adb_gsearch.best_estimator_
# Out:
# AdaBoostRegressor(base_estimator=GradientBoostingRegressor(random_state=42),
#                   learning_rate=0.001, loss='exponential', n_estimators=60,
#                   random_state=42)

# %% [markdown]
# ## Saving the Results

# %%
import json

# %%
random_forest = {'max_depth': 150, 'n_estimators':66, 'random_state':42}
gradient_boost = {'learning_rate':0.37500000000000006, 'max_depth':2,  'n_estimators':60, 'n_iter_no_change':5, 
                    'random_state':42, 'subsample':0.92, 'validation_fraction':0.15}
adaboost = {'base_estimator':'GradientBoostingRegressor(random_state=42)', 'learning_rate':0.001, 
                'loss':'exponential', 'n_estimators':60, 'random_state':42}

hyperparams = {'random_forest':random_forest, 'gradient_boost':gradient_boost, 'adaboost':adaboost}

# %%
with open('tuned_hyperparams.json', 'w') as file:
    json.dump(hyperparams, file)
